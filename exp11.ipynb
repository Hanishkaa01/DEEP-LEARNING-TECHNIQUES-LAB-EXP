# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanishkaa01/DEEP-LEARNING-TECHNIQUES-LAB-EXP/blob/main/exp11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf # Import tensorflow
from tensorflow.keras import layers, models, backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model # Import Model


# Step 1: Load and Prepare Data
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.

x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))


# Step 2: Define the VAE Architecture
latent_dim = 2  # Latent space dimension (for visualization)

# --- Encoder ---
encoder_inputs = layers.Input(shape=(28, 28, 1))
x = layers.Flatten()(encoder_inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dense(128, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

# Reparameterization trick
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

encoder = models.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

# --- Decoder ---
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(128, activation="relu")(latent_inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dense(28 * 28, activation="sigmoid")(x)
decoder_outputs = layers.Reshape((28, 28, 1))(x)

decoder = models.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

# ------------------------------------------------------------
# Step 3: Define VAE Model with Custom Loss
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                binary_crossentropy(tf.reshape(data, [-1]), tf.reshape(reconstruction, [-1]))
            )
            reconstruction_loss *= 28 * 28
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            binary_crossentropy(tf.reshape(data, [-1]), tf.reshape(reconstruction, [-1]))
        )
        reconstruction_loss *= 28 * 28
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + kl_loss
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }


vae = VAE(encoder, decoder)
vae.compile(optimizer=Adam(learning_rate=0.001))
vae.summary()

# ------------------------------------------------------------
# Step 4: Train the VAE
history = vae.fit(x_train, epochs=30, batch_size=256, validation_data=(x_test, None))

# ------------------------------------------------------------
# Step 5: Visualize Training Loss
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('VAE Training Loss')
plt.legend()
plt.show()

# ------------------------------------------------------------
# Step 6: Reconstruct Images
z_mean, _, _ = encoder.predict(x_test)
reconstructed = vae.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis("off")

    # Reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed[i].reshape(28, 28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()

# ------------------------------------------------------------
# Step 7: Latent Space Visualization
if latent_dim == 2:
    plt.figure(figsize=(8, 6))
    z_mean, _, _ = encoder.predict(x_test) # Recalculate z_mean for plotting
    plt.scatter(z_mean[:, 0], z_mean[:, 1], s=2, alpha=0.5)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.title("Latent Space Distribution")
    plt.show()

# ------------------------------------------------------------
# Step 8: Generate New Digits from Latent Space
if latent_dim == 2:
    n = 15  # grid size
    digit_size = 28
    figure = np.zeros((digit_size * n, digit_size * n))

    # Linearly spaced coordinates corresponding to the latent space
    grid_x = np.linspace(-3, 3, n)
    grid_y = np.linspace(-3, 3, n)

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[i * digit_size: (i + 1) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = digit

    plt.figure(figsize=(10, 10))
    plt.imshow(figure, cmap='gray')
    plt.title("Generated Digits from Latent Space")
    plt.axis("off")
    plt.show()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 784)       │          0 │ input_layer_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 256)       │    200,960 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 128)       │     32,896 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │        258 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 2)         │        258 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Lambda)          │ (None, 2)         │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 234,372 (915.52 KB)
#  Trainable params: 234,372 (915.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 784)            │       201,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 28, 28, 1)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 234,896 (917.56 KB)
#  Trainable params: 234,896 (917.56 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "vae_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Functional)            │ ((None, 2), (None, 2), │       234,372 │
# │                                 │ (None, 2))             │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 28, 28, 1)      │       234,896 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 469,268 (1.79 MB)
#  Trainable params: 469,268 (1.79 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - kl_loss: 8.9875 - loss: 269.0077 - reconstruction_loss: 260.0202 - val_kl_loss: 4.8431 - val_loss: 186.0067 - val_reconstruction_loss: 181.1636
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - kl_loss: 4.2939 - loss: 176.8910 - reconstruction_loss: 172.5972 - val_kl_loss: 5.4197 - val_loss: 171.9944 - val_reconstruction_loss: 166.5747
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 4.8068 - loss: 167.8510 - reconstruction_loss: 163.0443 - val_kl_loss: 5.3006 - val_loss: 162.6510 - val_reconstruction_loss: 157.3504
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - kl_loss: 5.0792 - loss: 163.0506 - reconstruction_loss: 157.9714 - val_kl_loss: 5.4495 - val_loss: 157.8874 - val_reconstruction_loss: 152.4379
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - kl_loss: 5.3119 - loss: 159.8771 - reconstruction_loss: 154.5652 - val_kl_loss: 5.8206 - val_loss: 155.8905 - val_reconstruction_loss: 150.0699
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - kl_loss: 5.4970 - loss: 157.4543 - reconstruction_loss: 151.9573 - val_kl_loss: 5.8462 - val_loss: 154.4204 - val_reconstruction_loss: 148.5742
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - kl_loss: 5.5753 - loss: 155.8002 - reconstruction_loss: 150.2250 - val_kl_loss: 5.9376 - val_loss: 153.6897 - val_reconstruction_loss: 147.7521
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - kl_loss: 5.6853 - loss: 154.2711 - reconstruction_loss: 148.5858 - val_kl_loss: 5.8062 - val_loss: 150.4730 - val_reconstruction_loss: 144.6668
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 5.7462 - loss: 153.3079 - reconstruction_loss: 147.5618 - val_kl_loss: 5.9412 - val_loss: 152.2907 - val_reconstruction_loss: 146.3495
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - kl_loss: 5.8048 - loss: 152.5759 - reconstruction_loss: 146.7711 - val_kl_loss: 6.1853 - val_loss: 149.9351 - val_reconstruction_loss: 143.7498
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - kl_loss: 5.8855 - loss: 150.9979 - reconstruction_loss: 145.1124 - val_kl_loss: 6.0437 - val_loss: 151.3060 - val_reconstruction_loss: 145.2623
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 5.9129 - loss: 150.2617 - reconstruction_loss: 144.3488 - val_kl_loss: 6.0367 - val_loss: 147.0967 - val_reconstruction_loss: 141.0600
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 5.9544 - loss: 149.2900 - reconstruction_loss: 143.3356 - val_kl_loss: 6.1698 - val_loss: 148.0524 - val_reconstruction_loss: 141.8826
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 5.9984 - loss: 148.9897 - reconstruction_loss: 142.9913 - val_kl_loss: 5.9528 - val_loss: 148.9044 - val_reconstruction_loss: 142.9516
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - kl_loss: 6.0307 - loss: 148.4545 - reconstruction_loss: 142.4239 - val_kl_loss: 6.0942 - val_loss: 147.3191 - val_reconstruction_loss: 141.2249
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - kl_loss: 6.0610 - loss: 148.0397 - reconstruction_loss: 141.9787 - val_kl_loss: 6.3396 - val_loss: 148.8986 - val_reconstruction_loss: 142.5590
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - kl_loss: 6.1227 - loss: 147.2106 - reconstruction_loss: 141.0879 - val_kl_loss: 6.1063 - val_loss: 148.9031 - val_reconstruction_loss: 142.7968
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 6.1467 - loss: 146.4247 - reconstruction_loss: 140.2779 - val_kl_loss: 6.2246 - val_loss: 147.9983 - val_reconstruction_loss: 141.7737
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - kl_loss: 6.1901 - loss: 146.6906 - reconstruction_loss: 140.5005 - val_kl_loss: 6.2809 - val_loss: 147.3621 - val_reconstruction_loss: 141.0811
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - kl_loss: 6.2196 - loss: 146.4022 - reconstruction_loss: 140.1826 - val_kl_loss: 6.2814 - val_loss: 146.4491 - val_reconstruction_loss: 140.1678
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 6.2575 - loss: 145.4326 - reconstruction_loss: 139.1751 - val_kl_loss: 6.3244 - val_loss: 145.8462 - val_reconstruction_loss: 139.5219
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - kl_loss: 6.2573 - loss: 145.6653 - reconstruction_loss: 139.4080 - val_kl_loss: 6.3042 - val_loss: 144.6787 - val_reconstruction_loss: 138.3745
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - kl_loss: 6.2732 - loss: 144.8016 - reconstruction_loss: 138.5284 - val_kl_loss: 6.3409 - val_loss: 145.4551 - val_reconstruction_loss: 139.1142
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 6.3139 - loss: 144.8924 - reconstruction_loss: 138.5785 - val_kl_loss: 6.3001 - val_loss: 145.0595 - val_reconstruction_loss: 138.7594
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - kl_loss: 6.3406 - loss: 144.7164 - reconstruction_loss: 138.3758 - val_kl_loss: 6.2011 - val_loss: 145.1399 - val_reconstruction_loss: 138.9388
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - kl_loss: 6.3355 - loss: 144.1701 - reconstruction_loss: 137.8346 - val_kl_loss: 6.4382 - val_loss: 144.8412 - val_reconstruction_loss: 138.4031
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - kl_loss: 6.3948 - loss: 143.6944 - reconstruction_loss: 137.2995 - val_kl_loss: 6.2661 - val_loss: 144.2545 - val_reconstruction_loss: 137.9884
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 6.3747 - loss: 143.6561 - reconstruction_loss: 137.2814 - val_kl_loss: 6.3148 - val_loss: 144.4290 - val_reconstruction_loss: 138.1141
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - kl_loss: 6.3900 - loss: 143.5907 - reconstruction_loss: 137.2007 - val_kl_loss: 6.3166 - val_loss: 145.4936 - val_reconstruction_loss: 139.1770
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - kl_loss: 6.4172 - loss: 143.2077 - reconstruction_loss: 136.7905 - val_kl_loss: 6.3084 - val_loss: 144.1064 - val_reconstruction_loss: 137.7980
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-605534011.py in <cell line: 0>()
#     135 # Step 6: Reconstruct Images
#     136 z_mean, _, _ = encoder.predict(x_test)
# --> 137 reconstructed = vae.predict(x_test)
#     138
#     139 n = 10
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/model.py in call(self, *args, **kwargs)
#     159
#     160     def call(self, *args, **kwargs):
# --> 161         raise NotImplementedError(
#     162             f"Model {self.__class__.__name__} does not have a `call()` "
#     163             "method implemented."
#
# NotImplementedError: Exception encountered when calling VAE.call().
#
# Model VAE does not have a `call()` method implemented.
#
# Arguments received by VAE.call():
#   • args=('tf.Tensor(shape=(32, 28, 28, 1), dtype=float32)',)
#   • kwargs=<class 'inspect._empty'>

# %%
# ============================================================
# Variational Autoencoder (VAE) - MNIST
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K
from tensorflow.keras.datasets import mnist

# ------------------------------------------------------------
# Data Preparation
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# ------------------------------------------------------------
# VAE Architecture
latent_dim = 2

# Encoder
encoder_inputs = layers.Input(shape=(28, 28, 1))
x = layers.Flatten()(encoder_inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dense(128, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# Decoder
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(128, activation="relu")(latent_inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dense(28 * 28, activation="sigmoid")(x)
decoder_outputs = layers.Reshape((28, 28, 1))(x)
decoder = Model(latent_inputs, decoder_outputs, name="decoder")

# ------------------------------------------------------------
# Custom VAE Model
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2, 3))
            )
            kl_loss = -0.5 * tf.reduce_mean(
                tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
            )
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {"loss": total_loss, "reconstruction_loss": reconstruction_loss, "kl_loss": kl_loss}

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

vae = VAE(encoder, decoder)
vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# ------------------------------------------------------------
# Training
history = vae.fit(x_train, epochs=30, batch_size=256, validation_data=(x_test, None))

# ------------------------------------------------------------
# Reconstruction
reconstructed = vae.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap="gray")
    plt.axis("off")
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed[i].reshape(28, 28), cmap="gray")
    plt.axis("off")
plt.show()

# ------------------------------------------------------------
# Latent Space Visualization
z_mean, _, _ = encoder.predict(x_test)
plt.figure(figsize=(8, 6))
plt.scatter(z_mean[:, 0], z_mean[:, 1], s=2, alpha=0.5)
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title("Latent Space")
plt.show()

# ------------------------------------------------------------
# Sampling / Generation
n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = np.linspace(-3, 3, n)
grid_y = np.linspace(-3, 3, n)

for i, yi in enumerate(grid_y):
    for j, xi in enumerate(grid_x):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2802831637.py in <cell line: 0>()
#      79 # ------------------------------------------------------------
#      80 # Training
# ---> 81 history = vae.fit(x_train, epochs=30, batch_size=256, validation_data=(x_test, None))
#      82
#      83 # ------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /tmp/ipython-input-2802831637.py in train_step(self, data)
#      60             reconstruction = self.decoder(z)
#      61             reconstruction_loss = tf.reduce_mean(
# ---> 62                 tf.reduce_sum(tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2, 3))
#      63             )
#      64             kl_loss = -0.5 * tf.reduce_mean(
#
# ValueError: Invalid reduction dimension 3 for input with 3 dimensions. for '{{node Sum}} = Sum[T=DT_FLOAT, Tidx=DT_INT32, keep_dims=false](Mean, Sum/reduction_indices)' with input shapes: [?,28,28], [3] and with computed input tensors: input[1] = <1 2 3>.

# %%
# ============================================================
# Variational Autoencoder (VAE) - MNIST
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K
from tensorflow.keras.datasets import mnist

# ------------------------------------------------------------
# Data Preparation
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# ------------------------------------------------------------
# VAE Architecture
latent_dim = 2

# Encoder
encoder_inputs = layers.Input(shape=(28, 28, 1))
x = layers.Flatten()(encoder_inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dense(128, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# Decoder
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(128, activation="relu")(latent_inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dense(28 * 28, activation="sigmoid")(x)
decoder_outputs = layers.Reshape((28, 28, 1))(x)
decoder = Model(latent_inputs, decoder_outputs, name="decoder")

# ------------------------------------------------------------
# Custom VAE Model
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2))
            )
            kl_loss = -0.5 * tf.reduce_mean(
                tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
            )
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {"reconstruction_loss": self.reconstruction_loss_tracker.result(), "kl_loss": self.kl_loss_tracker.result()}

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def test_step(self, data):
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2))
        )
        kl_loss = -0.5 * tf.reduce_mean(
            tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
        )
        total_loss = reconstruction_loss + kl_loss
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {"reconstruction_loss": self.reconstruction_loss_tracker.result(), "kl_loss": self.kl_loss_tracker.result()}


vae = VAE(encoder, decoder)
vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# ------------------------------------------------------------
# Training
history = vae.fit(x_train, epochs=30, batch_size=256, validation_data=x_test)

# ------------------------------------------------------------
# Reconstruction
reconstructed = vae.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap="gray")
    plt.axis("off")
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed[i].reshape(28, 28), cmap="gray")
    plt.axis("off")
plt.show()

# ------------------------------------------------------------
# Latent Space Visualization
z_mean, _, _ = encoder.predict(x_test)
plt.figure(figsize=(8, 6))
plt.scatter(z_mean[:, 0], z_mean[:, 1], s=2, alpha=0.5)
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.title("Latent Space")
plt.show()

# ------------------------------------------------------------
# Sampling / Generation
n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = np.linspace(-3, 3, n)
grid_y = np.linspace(-3, 3, n)

for i, yi in enumerate(grid_y):
    for j, xi in enumerate(grid_x):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - kl_loss: 10.0951 - reconstruction_loss: 257.8873 - val_kl_loss: 4.0952 - val_reconstruction_loss: 175.8425
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - kl_loss: 4.3199 - reconstruction_loss: 170.6059 - val_kl_loss: 4.9377 - val_reconstruction_loss: 162.9750
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - kl_loss: 4.8984 - reconstruction_loss: 161.5327 - val_kl_loss: 5.0223 - val_reconstruction_loss: 158.6783
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - kl_loss: 5.1112 - reconstruction_loss: 157.6767 - val_kl_loss: 5.2313 - val_reconstruction_loss: 155.5947
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - kl_loss: 5.3440 - reconstruction_loss: 154.0489 - val_kl_loss: 5.4457 - val_reconstruction_loss: 152.3254
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 5.5000 - reconstruction_loss: 151.4706 - val_kl_loss: 5.3396 - val_reconstruction_loss: 150.9213
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - kl_loss: 5.5985 - reconstruction_loss: 149.8563 - val_kl_loss: 5.5179 - val_reconstruction_loss: 149.2308
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - kl_loss: 5.6776 - reconstruction_loss: 148.5911 - val_kl_loss: 5.5827 - val_reconstruction_loss: 148.0869
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - kl_loss: 5.7714 - reconstruction_loss: 147.2466 - val_kl_loss: 5.8609 - val_reconstruction_loss: 146.3681
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 5.8537 - reconstruction_loss: 145.7426 - val_kl_loss: 5.9995 - val_reconstruction_loss: 145.4817
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - kl_loss: 5.8682 - reconstruction_loss: 145.2287 - val_kl_loss: 5.8607 - val_reconstruction_loss: 144.7097
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 5.9444 - reconstruction_loss: 143.8896 - val_kl_loss: 6.2009 - val_reconstruction_loss: 143.8494
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - kl_loss: 6.0022 - reconstruction_loss: 142.9615 - val_kl_loss: 5.9893 - val_reconstruction_loss: 143.2902
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 6.0583 - reconstruction_loss: 142.3790 - val_kl_loss: 6.0833 - val_reconstruction_loss: 142.7348
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - kl_loss: 6.0783 - reconstruction_loss: 141.7098 - val_kl_loss: 6.1220 - val_reconstruction_loss: 142.0239
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - kl_loss: 6.1496 - reconstruction_loss: 141.1102 - val_kl_loss: 5.9759 - val_reconstruction_loss: 141.7005
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - kl_loss: 6.1570 - reconstruction_loss: 140.8278 - val_kl_loss: 6.1996 - val_reconstruction_loss: 141.0618
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - kl_loss: 6.1974 - reconstruction_loss: 140.1713 - val_kl_loss: 6.1055 - val_reconstruction_loss: 140.7544
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - kl_loss: 6.2094 - reconstruction_loss: 139.5167 - val_kl_loss: 6.1793 - val_reconstruction_loss: 140.6230
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - kl_loss: 6.2427 - reconstruction_loss: 139.3448 - val_kl_loss: 6.1141 - val_reconstruction_loss: 140.1857
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 6.2729 - reconstruction_loss: 139.1680 - val_kl_loss: 6.3809 - val_reconstruction_loss: 139.5662
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - kl_loss: 6.3045 - reconstruction_loss: 138.4256 - val_kl_loss: 6.1481 - val_reconstruction_loss: 139.8885
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - kl_loss: 6.3075 - reconstruction_loss: 138.2523 - val_kl_loss: 6.3225 - val_reconstruction_loss: 139.1939
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - kl_loss: 6.3443 - reconstruction_loss: 138.1128 - val_kl_loss: 6.2761 - val_reconstruction_loss: 138.9386
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - kl_loss: 6.3492 - reconstruction_loss: 137.8974 - val_kl_loss: 6.2137 - val_reconstruction_loss: 139.1551
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - kl_loss: 6.3303 - reconstruction_loss: 137.8192 - val_kl_loss: 6.2492 - val_reconstruction_loss: 138.8386
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 6.3920 - reconstruction_loss: 137.3332 - val_kl_loss: 6.3396 - val_reconstruction_loss: 138.7950
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - kl_loss: 6.4065 - reconstruction_loss: 136.6456 - val_kl_loss: 6.3132 - val_reconstruction_loss: 138.4633
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - kl_loss: 6.4268 - reconstruction_loss: 136.5027 - val_kl_loss: 6.3406 - val_reconstruction_loss: 138.0575
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - kl_loss: 6.4627 - reconstruction_loss: 136.0784 - val_kl_loss: 6.3085 - val_reconstruction_loss: 138.3498
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
